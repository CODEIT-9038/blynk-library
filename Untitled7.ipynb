# %% [markdown]
# <a href="https://colab.research.google.com/github/CODEIT-9038/blynk-library/blob/master/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://www.gutenberg.org/files/68673/68673-h/68673.txt
# Out:
# --2022-08-03 15:23:11--  https://www.gutenberg.org/files/68673/68673-h/68673.txt
# Resolving www.gutenberg.org (www.gutenberg.org)... 152.19.134.47, 2610:28:3090:3000:0:bad:cafe:47
# Connecting to www.gutenberg.org (www.gutenberg.org)|152.19.134.47|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2022-08-03 15:23:11 ERROR 404: Not Found.

# %%
# !wget https://www.gutenberg.org/files/1661/1661-0.txt
# Out:
# --2022-08-03 15:24:42--  https://www.gutenberg.org/files/1661/1661-0.txt
# Resolving www.gutenberg.org (www.gutenberg.org)... 152.19.134.47, 2610:28:3090:3000:0:bad:cafe:47
# Connecting to www.gutenberg.org (www.gutenberg.org)|152.19.134.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 607430 (593K) [text/plain]
# Saving to: ‘1661-0.txt’
#
# 1661-0.txt          100%[===================>] 593.19K  3.26MB/s    in 0.2s
#
# 2022-08-03 15:24:42 (3.26 MB/s) - ‘1661-0.txt’ saved [607430/607430]

# %%
# !wget https://www.gutenberg.org/files/68673/68673-h/68673.txt
# Out:
# --2022-08-03 15:26:00--  https://www.gutenberg.org/files/68673/68673-h/68673.txt
# Resolving www.gutenberg.org (www.gutenberg.org)... 152.19.134.47, 2610:28:3090:3000:0:bad:cafe:47
# Connecting to www.gutenberg.org (www.gutenberg.org)|152.19.134.47|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2022-08-03 15:26:00 ERROR 404: Not Found.

# %%
# !wget https://www.gutenberg.org/cache/epub/68673/pg68673.txt
# Out:
# --2022-08-03 15:27:20--  https://www.gutenberg.org/cache/epub/68673/pg68673.txt
# Resolving www.gutenberg.org (www.gutenberg.org)... 152.19.134.47, 2610:28:3090:3000:0:bad:cafe:47
# Connecting to www.gutenberg.org (www.gutenberg.org)|152.19.134.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 213930 (209K) [text/plain]
# Saving to: ‘pg68673.txt’
#
# pg68673.txt         100%[===================>] 208.92K  --.-KB/s    in 0.1s
#
# 2022-08-03 15:27:20 (1.43 MB/s) - ‘pg68673.txt’ saved [213930/213930]

# %%
fp = open('pg68673.txt','r')

# %%
file_buffer= fp.read()

# %%
type(file_buffer)
# Out:
# str

# %%
help (str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
len(file_buffer)
# Out:
# 209351

# %%
file_buffer
# Out:
# '\ufeffThe Project Gutenberg eBook of Outlaw Jack; or, the mountain devil,\nby Harry Hazard\n\nThis eBook is for the use of anyone anywhere in the United States and\nmost other parts of the world at no cost and with almost no restrictions\nwhatsoever. You may copy it, give it away or re-use it under the terms\nof the Project Gutenberg License included with this eBook or online at\nwww.gutenberg.org. If you are not located in the United States, you\nwill have to check the laws of the country where you are located before\nusing this eBook.\n\nTitle: Outlaw Jack; or, the mountain devil\n       Beadle\'s Pocket Novels No. 79\n\nAuthor: Harry Hazard\n\nRelease Date: August 3, 2022 [eBook #68673]\n\nLanguage: English\n\nProduced by: David Edwards, Mary Meehan and the Online Distributed\n             Proofreading Team at https://www.pgdp.net (Northern\n             Illinois University Digital Library).\n\n*** START OF THE PROJECT GUTENBERG EBOOK OUTLAW JACK; OR, THE MOUNTAIN\nDEVIL ***\n\n\
# ...

# %%
file_list= file_buffer.split()

# %%
type(file_list)
# Out:
# list

# %%
file_list
# Out:
# ['\ufeffThe',
#  'Project',
#  'Gutenberg',
#  'eBook',
#  'of',
#  'Outlaw',
#  'Jack;',
#  'or,',
#  'the',
#  'mountain',
#  'devil,',
#  'by',
#  'Harry',
#  'Hazard',
#  'This',
#  'eBook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'in',
#  'the',
#  'United',
#  'States',
#  'and',
#  'most',
#  'other',
#  'parts',
#  'of',
#  'the',
#  'world',
#  'at',
#  'no',
#  'cost',
#  'and',
#  'with',
#  'almost',
#  'no',
#  'restrictions',
#  'whatsoever.',
#  'You',
#  'may',
#  'copy',
#  'it,',
#  'give',
#  'it',
#  'away',
#  'or',
#  're-use',
#  'it',
#  'under',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'Project',
#  'Gutenberg',
#  'License',
#  'included',
#  'with',
#  'this',
#  'eBook',
#  'or',
#  'online',
#  'at',
#  'www.gutenberg.org.',
#  'If',
#  'you',
#  'are',
#  'not',
#  'located',
#  'in',
#  'the',
#  'United',
#  'States,',
#  'you',
#  'will',
#  'have',
#  'to',
#  'check',
#  'the',
#  'laws',
#  'of',
#  'the',
# ...

# %%
import collections as cc

# %%
file_collection = cc.Counter(file_list)

# %%
type(file_collection)
# Out:
# collections.Counter

# %%
file_collection
# Out:
# Counter({'\ufeffThe': 1,
#          'Project': 79,
#          'Gutenberg': 22,
#          'eBook': 6,
#          'of': 763,
#          'Outlaw': 2,
#          'Jack;': 2,
#          'or,': 2,
#          'the': 1879,
#          'mountain': 4,
#          'devil,': 5,
#          'by': 195,
#          'Harry': 13,
#          'Hazard': 2,
#          'This': 32,
#          'is': 180,
#          'for': 247,
#          'use': 15,
#          'anyone': 4,
#          'anywhere': 2,
#          'in': 408,
#          'United': 17,
#          'States': 8,
#          'and': 757,
#          'most': 15,
#          'other': 44,
#          'parts': 2,
#          'world': 3,
#          'at': 170,
#          'no': 87,
#          'cost': 2,
#          'with': 227,
#          'almost': 22,
#          'restrictions': 2,
#          'whatsoever.': 2,
#          'You': 53,
#          'may': 52,
#          'copy': 8,
#          'it,': 25,
#          'give': 23,
#          'it': 198,
#          'away': 13,
# ...

# %%
file_dict= dict(file_collection)

# %%
file_dict
# Out:
# {'\ufeffThe': 1,
#  'Project': 79,
#  'Gutenberg': 22,
#  'eBook': 6,
#  'of': 763,
#  'Outlaw': 2,
#  'Jack;': 2,
#  'or,': 2,
#  'the': 1879,
#  'mountain': 4,
#  'devil,': 5,
#  'by': 195,
#  'Harry': 13,
#  'Hazard': 2,
#  'This': 32,
#  'is': 180,
#  'for': 247,
#  'use': 15,
#  'anyone': 4,
#  'anywhere': 2,
#  'in': 408,
#  'United': 17,
#  'States': 8,
#  'and': 757,
#  'most': 15,
#  'other': 44,
#  'parts': 2,
#  'world': 3,
#  'at': 170,
#  'no': 87,
#  'cost': 2,
#  'with': 227,
#  'almost': 22,
#  'restrictions': 2,
#  'whatsoever.': 2,
#  'You': 53,
#  'may': 52,
#  'copy': 8,
#  'it,': 25,
#  'give': 23,
#  'it': 198,
#  'away': 13,
#  'or': 155,
#  're-use': 2,
#  'under': 14,
#  'terms': 20,
#  'License': 8,
#  'included': 2,
#  'this': 161,
#  'online': 4,
#  'www.gutenberg.org.': 2,
#  'If': 40,
#  'you': 245,
#  'are': 101,
#  'not': 209,
#  'located': 7,
#  'States,': 5,
#  'will': 98,
#  'have': 119,
#  'to': 719,
#  'check': 4,
#  'laws': 15,
#  'country': 7,
# ...

# %%
file_word_features= [(i ,j)for i,j in file_dict.items()if(len(i)<5 )and j>10 and j<20 ]

# %%
file_word_features
# Out:
# [('use', 15),
#  ('most', 15),
#  ('away', 13),
#  ('laws', 15),
#  ('OF', 11),
#  ('THE', 18),
#  ('poor', 13),
#  ('cry', 16),
#  ('men,', 11),
#  ('One', 15),
#  ('has', 17),
#  ('felt', 14),
#  ('whom', 12),
#  ('many', 11),
#  ('life', 13),
#  ('To', 11),
#  ('day,', 13),
#  ('took', 14),
#  ('"It', 17),
#  ('so,', 13),
#  ('us,', 14),
#  ('word', 15),
#  ('say', 14),
#  ('man,', 15),
#  ('wild', 17),
#  ('form', 18),
#  ('met', 15),
#  ('else', 17),
#  ('Nate', 13),
#  ('none', 13),
#  ('best', 17),
#  ("o'", 19),
#  ("an'", 18),
#  ('"And', 12),
#  ('on,', 11),
#  ('hope', 15),
#  ('now.', 13),
#  ('His', 14),
#  ('blow', 12),
#  ('low', 15),
#  ('you,', 12),
#  ('me,', 14),
#  ('"We', 16),
#  ('get', 18),
#  ('need', 14),
#  ("I'm", 13),
#  ('good', 18),
#  ("I'll", 11),
#  ('ever', 13),
#  ('keep', 18),
#  ('gold', 17),
#  ('At', 14),
#  ('said', 13),
#  ('last', 16),
#  ('She', 11),
#  ('free', 14),
#  ('out,', 11),
#  ('dark', 12),
#  ('low,', 11),
#  ('hear', 12),
# ...

# %%
file_feature_list= str(file_word_features)

# %%
fp2= open('file_feature_list','w')

# %%
fp2.write(file_feature_list)
# Out:
# 1050

# %%
fp.close()
fp2.close()

# %%
# !wget https://github.com/ckrathub/myfirstrepository-/blob/main/file_processing_and_container_data_types.ipynb
# Out:
# --2022-08-03 16:01:07--  https://github.com/ckrathub/myfirstrepository-/blob/main/file_processing_and_container_data_types.ipynb
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘file_processing_and_container_data_types.ipynb’
#
# file_processing_and     [ <=>                ] 141.48K  --.-KB/s    in 0.08s
#
# 2022-08-03 16:01:08 (1.77 MB/s) - ‘file_processing_and_container_data_types.ipynb’ saved [144880]

# %%
fp = open('file_processing_and_container_data_types.ipynb','r')

# %%
file_buffer=fp.read()

# %%
type(file_buffer)
# Out:
# str

# %%
file_buffer
# Out:
# ''

# %%
len(file_buffer)
# Out:
# 0

# %%
file_list= file_buffer.split()

# %%
file_list
# Out:
# []

# %%
import collections as cc

# %%
file_counter= cc.Counter(file_list)

# %%
file_list
# Out:
# []

# %%
file_dict= dict(file_list)
